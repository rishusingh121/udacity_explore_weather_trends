# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\hp\Documents\Python learning\nanodegree\p1_weather_trends\result.csv')

# %%
data.head(15)
# Out:
#     year   gat  mA_gat    cat    mA_cat
# 0   1796  8.27     NaN  25.03       NaN
# 1   1797  8.51     NaN  26.71       NaN
# 2   1798  8.67     NaN  24.29       NaN
# 3   1799  8.51     NaN  25.28       NaN
# 4   1800  8.48     NaN  25.21       NaN
# 5   1801  8.59     NaN  24.22       NaN
# 6   1802  8.58     NaN  25.63       NaN
# 7   1803  8.50     NaN  25.38       NaN
# 8   1804  8.84     NaN  25.68       NaN
# 9   1805  8.56   8.551  25.30  25.27300
# 10  1806  8.43   8.567  25.22  25.29200
# 11  1807  8.28   8.544  24.97  25.11800
# 12  1808  7.63   8.440    NaN  25.21000
# 13  1809  7.08   8.297    NaN  25.20125
# 14  1810  6.92   8.141    NaN  25.20000

# %%
# Drawing the graph for New Delhi and Global Temperature
plt.plot(data.year, data.mA_cat, label='New Delhi')
plt.plot(data.year, data.mA_gat, label='Global')
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)")
plt.title("New Delhi Vs Global Average Temperature")
plt.show()
